# %%
import pandas as pd

# %%
info = {
    "Name":["rohan" , "rahul" , "manas" , "chinmay"],
    "Roll Nos" : [128 , 5 , 11 , 10],
    "cgpa" : [9 , 7.8 , 8.9 , 2]
}
s = pd.DataFrame(info)
print(s)
# Out:
#       Name  Roll Nos  cgpa
# 0    rohan       128   9.0
# 1    rahul         5   7.8
# 2    manas        11   8.9
# 3  chinmay        10   2.0

# %%
s
# Out:
#       Name  Roll Nos  cgpa
# 0    rohan       128   9.0
# 1    rahul         5   7.8
# 2    manas        11   8.9
# 3  chinmay        10   2.0

# %%
s = pd.Series(info )
print(s)
# Out:
# Name        [rohan, rahul, manas, chinmay]
# Roll Nos                  [128, 5, 11, 10]
# cgpa                      [9, 7.8, 8.9, 2]
# dtype: object

# %%
list_panda = pd.Series([1 ,4 ,5 , 9] , index = ["eve" , "adam" , "alpa" , "bita"])
print(list_panda , type(list_panda))
print(list_panda["eve"])
# Out:
# eve     1
# adam    4
# alpa    5
# bita    9
# dtype: int64 <class 'pandas.Series'>
# 1

# %% [raw]
# property of Series

# %%
#vectorization
list_1 = pd.Series([2,4,5,6])
s = list_1 ** 2
print(list_1)
# Out:
# 0    2
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
#homonious data
list_2 = pd.Series([1,4,5,"bob"])
print(list_2)
# Out:
# 0      1
# 1      4
# 2      5
# 3    bob
# dtype: object

# %%
#mutable value , inmutable size
list_3 = pd.Series([2,5,6,8])
print(list_3.drop(3))
print(list_3)
# Out:
# 0    2
# 1    5
# 2    6
# dtype: int64
# 0    2
# 1    5
# 2    6
# 3    8
# dtype: int64

# %% [raw]
# Dataframe(2D labeled Array)
# 1-dictionary
# 2-list of list
# 3-numpy array

# %%
#1
intro_dis = pd.DataFrame({
    "Name":["bob" , "abhishekh" , "devashis"],
    "branch":["IT" , "E&T" , "EEE"]
})

# %%
print(intro_dis)
# Out:
#         Name branch
# 0        bob     IT
# 1  abhishekh    E&T
# 2   devashis    EEE

# %%
intro_list = pd.DataFrame([["zibbey" ,  200] , ["uno-Audino" , 800] , ["rasberry pie" ,1000] ], columns = ["component" , "cost"])
print(intro_list)
# Out:
#       component  cost
# 0        zibbey   200
# 1    uno-Audino   800
# 2  rasberry pie  1000

# %%
#3
import numpy as np
from typing import List

# %%
num = np.array([[2,3] , [4,6]])
num_1 = pd.DataFrame(num , columns = ["A" , "B"])
print(num_1)
# Out:
#    A  B
# 0  2  3
# 1  4  6
