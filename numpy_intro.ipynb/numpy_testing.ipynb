# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np
import time

size = 10_00_000
python_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in python_list]

end = time.time()

print("Time take by python" , end-start , "second")

numpy_array = np.array(python_list)
start = time.time()
sq_array = numpy_array ** 2
end = time.time()
print("Time take by array" , end-start , "second" )
# Out:
# Time take by python 0.17278075218200684 second
# Time take by array 0.008078813552856445 second
